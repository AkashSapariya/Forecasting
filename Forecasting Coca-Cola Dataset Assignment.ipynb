# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# %matplotlib inline   
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 6

# %%
coca = pd.read_excel('D:/Data Science/Assignments/Forecasting/CocaCola_Sales_Rawdata.xlsx',header=0, index_col=0,parse_dates=True)
coca
# Out:
#                Sales
# Quarter
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996
# Q2_87    2104.411995
# Q3_87    2014.362999
# Q4_87    1991.746998
# Q1_88    1869.049999
# Q2_88    2313.631996
# Q3_88    2128.320000
# Q4_88    2026.828999
# Q1_89    1910.603996
# Q2_89    2331.164993
# Q3_89    2206.549995
# Q4_89    2173.967995
# Q1_90    2148.278000
# Q2_90    2739.307999
# Q3_90    2792.753998
# Q4_90    2556.009995
# Q1_91    2480.973999
# Q2_91    3039.522995
# Q3_91    3172.115997
# Q4_91    2879.000999
# Q1_92    2772.000000
# Q2_92    3550.000000
# Q3_92    3508.000000
# Q4_92    3243.859993
# Q1_93    3056.000000
# Q2_93    3899.000000
# Q3_93    3629.000000
# Q4_93    3373.000000
# Q1_94    3352.000000
# Q2_94    4342.000000
# Q3_94    4461.000000
# Q4_94    4017.000000
# Q1_95    3854.000000
# Q2_95    4936.000000
# Q3_95    4895.000000
# Q4_95    4333.000000
# Q1_96    4194.000000
# Q2_96    5253.000000

# %%
coca.head()
# Out:
#                Sales
# Quarter
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996

# %%
coca.shape
# Out:
# (42, 1)

# %%
coca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42 entries, Q1_86 to Q2_96
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   42 non-null     float64
# dtypes: float64(1)
# memory usage: 672.0+ bytes

# %%
coca.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %%
coca.plot()
plt.show()

# %% [markdown]
# #### Histogram Plot

# %%
coca.hist()
plt.show()

# %% [markdown]
# ####  Density Plot

# %%
coca.plot(kind='kde')
plt.show()

# %% [markdown]
# #### Lag Plot

# %%
from pandas.plotting import lag_plot

lag_plot(coca)
plt.show()

# %% [markdown]
# #### Autocorrelation plot

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(coca,lags=30)
plt.show()

# %%
coca = pd.read_excel('D:/Data Science/Assignments/Forecasting/CocaCola_Sales_Rawdata.xlsx')
coca
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
quarter=['Q1','Q2','Q3','Q4']
year=['86','87','88','89','90','91','92','93','94','95','96']
n=coca['Quarter'][0]
n[0:2]
n
# Out:
# 'Q1_86'

# %%
coca['quarter']=0
coca.head()
# Out:
#   Quarter        Sales  quarter
# 0   Q1_86  1734.827000        0
# 1   Q2_86  2244.960999        0
# 2   Q3_86  2533.804993        0
# 3   Q4_86  2154.962997        0
# 4   Q1_87  1547.818996        0

# %%
for i in range(42):
    n=coca['Quarter'][i]
    coca['quarter'][i]=n[0:2]
# Out:
# C:\Users\parth\AppData\Local\Temp\ipykernel_14164\358998096.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coca['quarter'][i]=n[0:2]

# %%
coca.head()
# Out:
#   Quarter        Sales quarter
# 0   Q1_86  1734.827000      Q1
# 1   Q2_86  2244.960999      Q2
# 2   Q3_86  2533.804993      Q3
# 3   Q4_86  2154.962997      Q4
# 4   Q1_87  1547.818996      Q1

# %%
cocacola = pd.get_dummies(coca['quarter'])

# %%
cocacola.head()
# Out:
#    Q1  Q2  Q3  Q4
# 0   1   0   0   0
# 1   0   1   0   0
# 2   0   0   1   0
# 3   0   0   0   1
# 4   1   0   0   0

# %%
cocadata = pd.concat([coca, cocacola], axis = 1)

# %%
cocadata.head()
# Out:
#   Quarter        Sales quarter  Q1  Q2  Q3  Q4
# 0   Q1_86  1734.827000      Q1   1   0   0   0
# 1   Q2_86  2244.960999      Q2   0   1   0   0
# 2   Q3_86  2533.804993      Q3   0   0   1   0
# 3   Q4_86  2154.962997      Q4   0   0   0   1
# 4   Q1_87  1547.818996      Q1   1   0   0   0

# %% [markdown]
# #### Find T-Squared and Log Values

# %%
cocadata["t"] = np.arange(1,43)
cocadata["t_squared"] = cocadata["t"]*cocadata["t"]
cocadata.columns
cocadata["log_sales"] = np.log(cocadata["Sales"])

# %%
cocadata.head()
# Out:
#   Quarter        Sales quarter  Q1  Q2  Q3  Q4  t  t_squared  log_sales
# 0   Q1_86  1734.827000      Q1   1   0   0   0  1          1   7.458663
# 1   Q2_86  2244.960999      Q2   0   1   0   0  2          4   7.716443
# 2   Q3_86  2533.804993      Q3   0   0   1   0  3          9   7.837477
# 3   Q4_86  2154.962997      Q4   0   0   0   1  4         16   7.675529
# 4   Q1_87  1547.818996      Q1   1   0   0   0  5         25   7.344602

# %% [markdown]
# #### Splitting data

# %%
Train = cocadata.head(30)
Test = cocadata.tail(12)

# %%
Train
# Out:
#    Quarter        Sales quarter  Q1  Q2  Q3  Q4   t  t_squared  log_sales
# 0    Q1_86  1734.827000      Q1   1   0   0   0   1          1   7.458663
# 1    Q2_86  2244.960999      Q2   0   1   0   0   2          4   7.716443
# 2    Q3_86  2533.804993      Q3   0   0   1   0   3          9   7.837477
# 3    Q4_86  2154.962997      Q4   0   0   0   1   4         16   7.675529
# 4    Q1_87  1547.818996      Q1   1   0   0   0   5         25   7.344602
# 5    Q2_87  2104.411995      Q2   0   1   0   0   6         36   7.651791
# 6    Q3_87  2014.362999      Q3   0   0   1   0   7         49   7.608058
# 7    Q4_87  1991.746998      Q4   0   0   0   1   8         64   7.596767
# 8    Q1_88  1869.049999      Q1   1   0   0   0   9         81   7.533186
# 9    Q2_88  2313.631996      Q2   0   1   0   0  10        100   7.746574
# 10   Q3_88  2128.320000      Q3   0   0   1   0  11        121   7.663088
# 11   Q4_88  2026.828999      Q4   0   0   0   1  12        144   7.614228
# ...

# %%
Test
# Out:
#    Quarter   Sales quarter  Q1  Q2  Q3  Q4   t  t_squared  log_sales
# 30   Q3_93  3629.0      Q3   0   0   1   0  31        961   8.196712
# 31   Q4_93  3373.0      Q4   0   0   0   1  32       1024   8.123558
# 32   Q1_94  3352.0      Q1   1   0   0   0  33       1089   8.117312
# 33   Q2_94  4342.0      Q2   0   1   0   0  34       1156   8.376090
# 34   Q3_94  4461.0      Q3   0   0   1   0  35       1225   8.403128
# 35   Q4_94  4017.0      Q4   0   0   0   1  36       1296   8.298291
# 36   Q1_95  3854.0      Q1   1   0   0   0  37       1369   8.256867
# 37   Q2_95  4936.0      Q2   0   1   0   0  38       1444   8.504311
# 38   Q3_95  4895.0      Q3   0   0   1   0  39       1521   8.495970
# 39   Q4_95  4333.0      Q4   0   0   0   1  40       1600   8.374015
# 40   Q1_96  4194.0      Q1   1   0   0   0  41       1681   8.341410
# 41   Q2_96  5253.0      Q2   0   1   0   0  42       1764   8.566555

# %%
#Determine rolling statistics
rolmean = cocadata.rolling(window=12).mean() #window size 12 denotes 12 months, giving rolling mean at yearly level
rolstd = cocadata.rolling(window=12).std()
print(rolmean,rolstd)
# Out:
#           Sales    Q1    Q2    Q3    Q4     t    t_squared  log_sales
# 0           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 1           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 2           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 3           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 4           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 5           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 6           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 7           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 8           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 9           NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 10          NaN   NaN   NaN   NaN   NaN   NaN          NaN        NaN
# 11  2055.393998  0.25  0.25  0.25  0.25   6.5    54.166667   7.620534
# ...

# %%
plt.figure(figsize=(12,4))
cocadata.Sales.plot(label="org")
for i in range(2,12,2):
   cocadata["Sales"].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best')

# %%
#Linear Model
import statsmodels.formula.api as smf 

linear_model = smf.ols('Sales~t',data=Train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(Test['t'])))
rmse_linear = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_linear))**2))
print("Root Mean Square Error : ",rmse_linear)
# Out:
# Root Mean Square Error :  714.0144483281297

# %%
#Exponential

Exp = smf.ols('log_sales~t',data=Train).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(Test['t'])))
rmse_Exp = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Exp)))**2))
print("Root Mean Square Error : ",rmse_Exp)
# Out:
# Root Mean Square Error :  552.2821039079295

# %%
#Quadratic 

Quad = smf.ols('Sales~t+t_squared',data=Train).fit()
pred_Quad = pd.Series(Quad.predict(Test[["t","t_squared"]]))
rmse_Quad = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_Quad))**2))
print("Root Mean Square Error : ",rmse_Quad)
# Out:
# Root Mean Square Error :  646.2715428311323

# %%
#Additive seasonality 

add_sea = smf.ols('Sales~Q1+Q2+Q3+Q4',data=Train).fit()
pred_add_sea = pd.Series(add_sea.predict(Test[['Q1','Q2','Q3','Q4']]))
rmse_add_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_add_sea))**2))
print("Root Mean Square Error : ",rmse_add_sea)
# Out:
# Root Mean Square Error :  1778.0065467941363

# %%
#Additive Seasonality Quadratic 

add_sea_Quad = smf.ols('Sales~t+t_squared+Q1+Q2+Q3+Q4',data=Train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(Test[['Q1','Q2','Q3','Q4','t','t_squared']]))
rmse_add_sea_quad = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(pred_add_sea_quad))**2))
print("Root Mean Square Error : ",rmse_add_sea_quad)
# Out:
# Root Mean Square Error :  586.0533067871024

# %%
##Multiplicative Seasonality

Mul_sea = smf.ols('log_sales~Q1+Q2+Q3+Q4',data = Train).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(Test))
rmse_Mult_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Mult_sea)))**2))
print("Root Mean Square Error : ",rmse_Mult_sea)
# Out:
# Root Mean Square Error :  1828.9238912138073

# %%
#Multiplicative Additive Seasonality 

Mul_Add_sea = smf.ols('log_sales~t+Q1+Q2+Q3+Q4',data = Train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(Test))
rmse_Mult_add_sea = np.sqrt(np.mean((np.array(Test['Sales'])-np.array(np.exp(pred_Mult_add_sea)))**2))
print("Root Mean Square Error : ",rmse_Mult_add_sea)
# Out:
# Root Mean Square Error :  410.24970596078435

# %%
#Compare the results 

data = {"MODEL":pd.Series(["rmse_linear","rmse_Exp","rmse_Quad","rmse_add_sea","rmse_add_sea_quad","rmse_Mult_sea","rmse_Mult_add_sea"]),"RMSE_Values":pd.Series([rmse_linear,rmse_Exp,rmse_Quad,rmse_add_sea,rmse_add_sea_quad,rmse_Mult_sea,rmse_Mult_add_sea])}
table_rmse=pd.DataFrame(data)
table_rmse.sort_values(['RMSE_Values'])
# Out:
#                MODEL  RMSE_Values
# 6  rmse_Mult_add_sea   410.249706
# 1           rmse_Exp   552.282104
# 4  rmse_add_sea_quad   586.053307
# 2          rmse_Quad   646.271543
# 0        rmse_linear   714.014448
# 3       rmse_add_sea  1778.006547
# 5      rmse_Mult_sea  1828.923891

# %% [markdown]
# #### Predict for new time period

# %%
#Build the model on entire data set
model_full = smf.ols('log_sales~t+Q1+Q2+Q3+Q4',data=cocadata).fit()

# %%
pred_new  = pd.Series(model_full.predict(cocadata))
pred_new
# Out:
# 0     7.339224
# 1     7.579747
# 2     7.571328
# 3     7.491254
# 4     7.435892
# 5     7.676415
# 6     7.667996
# 7     7.587922
# 8     7.532561
# 9     7.773084
# 10    7.764665
# 11    7.684591
# 12    7.629229
# 13    7.869752
# 14    7.861333
# 15    7.781259
# 16    7.725898
# 17    7.966421
# 18    7.958002
# 19    7.877928
# 20    7.822566
# 21    8.063089
# 22    8.054670
# 23    7.974596
# 24    7.919235
# 25    8.159758
# 26    8.151339
# 27    8.071265
# 28    8.015903
# 29    8.256426
# 30    8.248007
# 31    8.167933
# 32    8.112572
# 33    8.353095
# 34    8.344676
# 35    8.264602
# 36    8.209240
# 37    8.449763
# 38    8.441344
# 39    8.361270
# 40    8.305909
# 41    8.546432
# dtype: float64

# %%
cocadata["forecasted_Sales"] = pd.Series(pred_new)

# %%
cocadata
# Out:
#    Quarter        Sales quarter  Q1  Q2  Q3  Q4   t  t_squared  log_sales  \
# 0    Q1_86  1734.827000      Q1   1   0   0   0   1          1   7.458663
# 1    Q2_86  2244.960999      Q2   0   1   0   0   2          4   7.716443
# 2    Q3_86  2533.804993      Q3   0   0   1   0   3          9   7.837477
# 3    Q4_86  2154.962997      Q4   0   0   0   1   4         16   7.675529
# 4    Q1_87  1547.818996      Q1   1   0   0   0   5         25   7.344602
# 5    Q2_87  2104.411995      Q2   0   1   0   0   6         36   7.651791
# 6    Q3_87  2014.362999      Q3   0   0   1   0   7         49   7.608058
# 7    Q4_87  1991.746998      Q4   0   0   0   1   8         64   7.596767
# 8    Q1_88  1869.049999      Q1   1   0   0   0   9         81   7.533186
# 9    Q2_88  2313.631996      Q2   0   1   0   0  10        100   7.746574
# 10   Q3_88  2128.320000      Q3   0   0   1   0  11        121   7.663088
# 11   Q4_88  2026.828999      Q4   0   0   0   1  12        144   7.614228
# ...
